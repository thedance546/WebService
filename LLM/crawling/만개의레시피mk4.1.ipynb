# %%
import requests
import json
from bs4 import BeautifulSoup
import re
import time
import csv
import os
import string

def clean_text(text):
    # 한글, 영어, 숫자, 기본적인 문장 부호 및 연산 기호만 남기고 나머지 제거
    return re.sub(r'[^ㄱ-ㅣ가-힣a-zA-Z0-9\s\-\+\=\!\?\,\.\:\;\/\(\)\[\]\{\}\&\*\"\'\~\#\<\>\@]', '', text)


def convert_time(total_time):
    # PT 제거 및 H, M 변환
    match = re.match(r"PT(?:(\d+)H)?(?:(\d+)M)?", total_time)
    if match:
        hours = int(match.group(1) or 0)
        minutes = int(match.group(2) or 0)
        return f"{hours * 60 + minutes} minutes"
    return ""

def extract_yield(recipe_yield):
    # 숫자만 추출
    match = re.search(r"(\d+)", recipe_yield)
    return match.group(1) if match else ""

# %%
#페이지의 목록을 가져오는 함수
def fetch_recipes(patterns, output_file):
    all_recipe_ids = set()

    for pattern in patterns:
        page = 1
        while True:
            base_url = f"https://m.10000recipe.com/recipe/list.html?q={pattern}&order=reco&page={page}"
            attempt = 0
            while attempt < 5:
                try:
                    response = requests.get(base_url, timeout=10)
                    print(f"{page}페이지 요청: {pattern}")

                    if response.status_code == 200:
                        soup = BeautifulSoup(response.text, 'html.parser')

                        # "검색결과가 없습니다." 텍스트 확인
                        no_result_text = soup.find(string="검색결과가 없습니다.")
                        if no_result_text:
                            print(f"{pattern}의 {page}페이지에서 더 이상 검색결과가 없습니다.")
                            break

                        # 레시피 목록 추출
                        divs = soup.find_all('div', {'class': 'media'})
                        if not divs:
                            print(f"{pattern}의 {page}페이지에서 더 이상 레시피가 없습니다.")
                            break

                        for div in divs:
                            onclick = div.get('onclick', '')
                            match = re.search(r"/recipe/(\d+)", onclick)
                            if match:
                                recipe_id = match.group(1)
                                all_recipe_ids.add(recipe_id)

                        page += 1  # 다음 페이지로 이동
                        break  # 성공 시 재시도 루프 종료

                    else:
                        print(f"{pattern}의 {page}페이지 요청에 실패했습니다.")
                        break

                except requests.RequestException as e:
                    print(f"Error occurred while requesting {base_url}: {e}")
                    attempt += 1
                    if attempt < 5:
                        print(f"Retrying in 5 minutes... Attempt {attempt}/5")
                        time.sleep(300)
                    else:
                        print("Max retries reached, skipping this page.")
                        break

            if no_result_text:  # 결과 없음이 확인되면 패턴 종료
                break

    # 파일이 없으면 자동 생성하여 저장
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            for recipe_id in sorted(all_recipe_ids):
                f.write(recipe_id + '\n')
        print(f"총 {len(all_recipe_ids)}개의 레시피 ID가 {output_file}에 저장되었습니다.")
    except Exception as e:
        print(f"파일 저장 중 에러가 발생했습니다: {e}")

# %%
def recipecsv(data_file, output_csv_prefix, file_index):
    processed_ids = set()
    current_file_index = file_index
    current_count = 0
    output_csv = f"{output_csv_prefix}_{current_file_index}.csv"

    # 기존 데이터 로드
    if os.path.exists(output_csv):
        with open(output_csv, mode='r', encoding='utf-8') as file:
            reader = csv.DictReader(file)
            processed_ids = {row['id'] for row in reader}
            current_count = sum(1 for _ in reader)

    with open(data_file, 'r') as f:
        recipe_ids = [line.strip() for line in f]

    # 레시피 ID를 순회하며 처리
    remaining_ids = []
    for recipe_id in recipe_ids:
        if recipe_id in processed_ids:
            print(f"이미 처리된 레시피 ID: {recipe_id}")
            continue

        url = f"https://m.10000recipe.com/recipe/{recipe_id}"
        attempt = 0

        while attempt < 5:
            try:
                response = requests.get(url, timeout=10)
                if response.status_code == 200:
                    soup = BeautifulSoup(response.text, 'html.parser')
                    script_tag = soup.find('script', type='application/ld+json')
                    if script_tag:
                        raw_json = script_tag.string
                        fixed_json = re.sub(r'\}\s*\{', '},{', raw_json)

                        try:
                            data = json.loads(fixed_json)

                            # 데이터 추출 및 클리닝
                            name = clean_text(data.get('name', ''))
                            description = clean_text(data.get('description', ''))
                            image = data.get('image', '')
                            total_time = convert_time(data.get('totalTime', ''))
                            recipe_yield = extract_yield(data.get('recipeYield', ''))
                            ingredients = clean_text(','.join(data.get('recipeIngredient', [])))
                            recipe_steps = [clean_text(step.get('text', '')) for step in data.get('recipeInstructions', [])]

                            if not (name and ingredients and recipe_steps):
                                print(f"레시피 ID {recipe_id}에 본문 데이터가 없어 건너뜁니다.")
                                break

                            # 현재 CSV 파일 열기
                            with open(output_csv, mode='a', newline='', encoding='utf-8') as file:
                                fieldnames = ['id', 'name', 'ingredients', 'recipe', 'description', 'image', 'totalTime', 'recipeYield']
                                writer = csv.DictWriter(file, fieldnames=fieldnames)

                                if file.tell() == 0:
                                    writer.writeheader()

                                writer.writerow({
                                    'id': recipe_id,
                                    'name': name,
                                    'ingredients': ingredients,
                                    'recipe': ' '.join(recipe_steps),
                                    'image': image,
                                    'description': description,
                                    'totalTime': total_time,
                                    'recipeYield': recipe_yield,
                                })

                            print(f"레시피 ID {recipe_id}가 {output_csv}에 저장되었습니다.")
                            processed_ids.add(recipe_id)
                            current_count += 1

                            # 10,000개 도달 시 새 파일로 전환
                            if current_count >= 10000:
                                print(f"{output_csv} 저장 완료. 다음 파일로 전환합니다.")
                                current_file_index += 1
                                output_csv = f"{output_csv_prefix}_{current_file_index}.csv"
                                current_count = 0

                            break

                        except json.JSONDecodeError as e:
                            print(f"JSON 데이터 파싱 실패: {e}\n수정된 JSON:\n{fixed_json}")
                            break
                    else:
                        print(f"레시피 ID {recipe_id}: JSON 데이터가 포함된 script 태그를 찾을 수 없습니다.")
                        break
                else:
                    print(f"레시피 ID {recipe_id} 요청 실패 (상태 코드: {response.status_code})")
                    break

            except requests.RequestException as e:
                print(f"Error occurred while requesting {url}: {e}")
                attempt += 1
                if attempt < 5:
                    print(f"Retrying in 5 minutes... Attempt {attempt}/5")
                    time.sleep(300)
                else:
                    print("Max retries reached, skipping this recipe.")
                    break

    # 처리되지 않은 ID 업데이트
    remaining_ids = [recipe_id for recipe_id in recipe_ids if recipe_id not in processed_ids]
    with open(data_file, 'w', encoding='utf-8') as f:
        f.write('\n'.join(remaining_ids))
    print(f"{data_file} 업데이트 완료: {len(remaining_ids)}개의 ID 남음.")

# %%
# 사용
patterns = ["토마토", "방울 토마토", "김치", "가지", "오이", "애호박", "팽이버섯", "새송이 버섯",
    "돼지고기", "닭고기", "소고기", "두부", "콩나물", "대파", "양파", "마늘", "시금치",
    "고추", "깻잎", "당근", "감자", "고구마", "계란", "무", "파프리카", "맛살", "쌀",
    "어묵", "사과", "비엔나 소시지"]  # 검색할 재료 패턴 목록
recipe_id_file = "recipe_ids.txt"  # 레시피 ID가 저장된 파일
output_csv = "recipe_data_part"  # 저장할 CSV 파일

##fetch_recipes(patterns, recipe_id_file)
recipecsv(recipe_id_file, output_csv, 8)
# Out:
# 레시피 ID 6915462에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6915508에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 33 (char 100)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "감자황태국만들기#원기회복에 좋아요~
# 뽀얀국물이 사골국 못지 않아요.",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/5e6d87619201b2fae0457c6609944e831_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/5e6d87619201b2fae0457c6609944e831.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "캔캔맘"
#     },
#     "datePublished": "2019-07-09T07:57:07+09:00",
#     "description": "딸래미가 몸살에 걸려 황태국 끓였어요. 요즘 감자도 포실포실 맛있구 감자 좋아하는 딸래미에게 딱이다 싶어 만들어 봤어요. 피로회복에도 도움을 준대요~"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "3"
#     }
#             ,"totalTime": "PT0H60M"
#             ,"recipeYield": "4 servings"
#         ,"recipeIngredient": ["황태채 3종이컵","감자 3개","무우 1/4개","양파 1/2개","다진마늘 1T","대파 1/2개","물 5국대접","집간장 2T","들기름 4T"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"황태채는 2~3센티 크기로 잘라 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/bb1551d16b38e62502b59f58e052c2691.jpg"},{"@type":"HowToStep","text":"감자,양파,무우,대파는 껍질을 까서 준비해 두어요. 보리새우,황태,다진마늘을 준비해요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/2d2d4c8135ae6264a8f9387905cae3841.jpg"},{"@type":"HowToStep","text":"자른 황태에 물 한컵을 넣어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/78ff7aaea0f764688e55a5819c4535fa1.jpg"},{"@type":"HowToStep","text":"들기름 4스푼을 넣어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/2f6af33c9d8b45c9dadffd52122f3ae81.jpg"},{"@type":"HowToStep","text":"황태를 조물 조물 묻혀 주세요. 들기름과 물이 잘베도록 해 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/a71993b08b27fd77bf8e6d001de659fe1.jpg"},{"@type":"HowToStep","text":"물을 넣고 황태를 넣고 끓여 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/1c01a282a3b9082bc4f90e19b1bff0201.jpg"},{"@type":"HowToStep","text":"무우는 3등분으로 나누어 나박하게 썰어 줍니다. 감자는 반으로 잘라 4등분으로 썰어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/087c33ec669a998e99b066de66bedbb51.jpg"},{"@type":"HowToStep","text":"나박썰기한 무우와 감자를 국에 넣어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/a7d2563c003c2df1ad8c8c4d4b49c1a21.jpg"},{"@type":"HowToStep","text":"준비해둔 보리새우를 넣어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/80d590ab5969302563a3a21f7b4fa31a1.jpg"},{"@type":"HowToStep","text":"30분정도 끓으면 뽀얀 국물이 나옵니다. 어슷어승 썰어 놓은 대파른 넣어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/0b9a529afd3621b86300110fa2c9ce6c1.jpg"},{"@type":"HowToStep","text":"다진마늘을 넣어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/510d263b637a97280e5ec5cebf4e68891.jpg"},{"@type":"HowToStep","text":"잘끓은 감자황태국에 집간장(국간장)2스푼을 넣어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/3be57ce9c8a5cf1d7386099e93afa4791.jpg"},{"@type":"HowToStep","text":"그릇에 담아 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/05/cbc39f19ae85b911e81f2d2b5d6ab0831.jpg"}]}
#
# 레시피 ID 6915511에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6915519에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 55 (char 122)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "감자삼겹고추장찌개 만들기#포근포근감자와 꼬들꼬들삼겹살의 만남~환상적이에요.
# 밥한그릇 뚝딱입니다!",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/10/8f7c6867a3bc8e0f72af3e8889bb1d501_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/10/8f7c6867a3bc8e0f72af3e8889bb1d501.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "캔캔맘"
#     },
#     "datePublished": "2019-07-10T07:24:49+09:00",
#     "description": "어릴적 어머니가 해주시던 감자삼겹고추장찌개 그맛을 가족들에게 맛보여 주고 싶네요. 포근포근한 감자와 오독오독 씹히는 삼겹살의 환상궁합!국물맛도 끝내 줍니다~^^"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "8"
#     }
#             ,"totalTime": "PT0H60M"
#             ,"recipeYield": "4 servings"
#         ,"recipeIngredient": ["돼지고기 300g","양파 1개","감자 2개","대파 1/2개","다시팩 1개","고추장 5T","고춧가루 2T","다진마늘 2T","물 800ml"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"냄비에 다시팩을 넣고 국물이 우러 나오게 끓여 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/13829d0730495e34c36f7113b2fca96b1.jpg"},{"@type":"HowToStep","text":"삼겹살은 3센티크기로 잘라 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/55529e1914fd63d1d16bdb2d4116443f1.jpg"},{"@type":"HowToStep","text":"그사이 감자는 반으로 자르고 또반을 자른뒤 3등분으로 잘라 주어요. 양파도 반으로 자르고 3등분으로 자른뒤 또 3등분으로 잘라 주어요. 대파는 어슷어슷 썰어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/d1758da68d80a083466787bdd3a9328b1.jpg"},{"@type":"HowToStep","text":"15분쯤 지나면 육수가 잘우러납니다. 다시팩을 건져 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/81fef783fcdc00455a1f5d10bb2be81e1.jpg"},{"@type":"HowToStep","text":"육수에 고추장,고춧가루를 넣어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/526d4c9fe9ffad6cd48569f0174b64761.jpg"},{"@type":"HowToStep","text":"국물이 팔팔 끓으면 삼겹살을 넣어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/a6423aa200d68cf3be698da9cdfe654a1.jpg"},{"@type":"HowToStep","text":"다진마늘을 넣어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/511cd43b512546ceb6dfbc1bd4da82ef1.jpg"},{"@type":"HowToStep","text":"썰어 놓은 감자와 양파를 넣어 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/da51c7c9496fd867074c52dc379084a21.jpg"},{"@type":"HowToStep","text":"20분정도 쎈불로 팔팔 끓여 주어요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/72e50253c55d74a25461e13db0ca46291.jpg"},{"@type":"HowToStep","text":"마지막으로 썰어 놓은 대파를 넣어 주면 완성!입니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/09/9837913d8646ae0eb0b239eea3393f661.jpg"}]}
#
# 레시피 ID 6915581에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6915782에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6915841에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6915906에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 35 (char 102)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "건강반찬~변비에 좋은 염장 다시마채무침
# ",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/dd6b1fd27588f52f66435d1da5a9cd541_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/dd6b1fd27588f52f66435d1da5a9cd541.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "왕눈이2"
#     },
#     "datePublished": "2019-07-17T00:10:28+09:00",
#     "description": "염장된 다시마채로 무침을 만들어서 밑반찬으로 건강한반찬으로 드셔보세요  "
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "7"
#     }
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "4 servings"
#         ,"recipeIngredient": ["염장 다시마채 500g","까나리액젓 3큰술","다진파 2큰술","다진마늘 1큰술","참기름 1큰술","통깨 1큰술"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"염장된 다시마채 500g을 준비해주세요 요즘은 이렇게 미역줄기가 아닌 염장된 다시마채가 나오네요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/113349248abd6d80f22c1d61f9c32e011.jpg"},{"@type":"HowToStep","text":"물에 한번 씻어서 다시마채에 붙어있는 소금을 씻어내세요 살살 비벼주시면서 2번정도  더 씻어 내세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/006316835c901757a24daddaeb85b9811.jpg"},{"@type":"HowToStep","text":"2번정도 씻으신 다시마채는 물에 담구시어 염분을 빼주세요 저는 30분정도 담구었다가  했습니다 각자의 입맛에 맛게  염분기를 조절하세요 염분이 제거된 다시마채는  채반에서 물기를 빼주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/2b13714e16a5e6f98f58b4c1511418871.jpg"},{"@type":"HowToStep","text":"물기를뺀 다시마채에 다진마늘 1/2큰술과 고추가루 2큰술/통깨 1큰술을 넣어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/1a5189755cd643d4123a1e18396ebadd1.jpg"},{"@type":"HowToStep","text":"저는 염분을 많이 제거했기에  까나리액젓 3큰술을 넣어서  감칠맛과 더불어 밑간을 했어요 염분기에 따라서 까나리액젓을 조절하시면 되세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/cb7ee5ee4e014e73073c55269f9d00a81.jpg"},{"@type":"HowToStep","text":"양념을 잘 섞어가면서 무쳐주시고 마지막으로 참기름을 넣어서 마무리해주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/60786b34f26b79534440fb28dd24b1c31.jpg"},{"@type":"HowToStep","text":"건강한반찬~변비에도 너무나 좋은 다시마채무침이 완성이 되었어요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/15/b88774dc52af6b2c7310ee7582449bf51.jpg"}]}
#
# 레시피 ID 6915966에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916008에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 20 (char 87)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "황금 레시피
# 파김치 맛있게 담그는 법",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/2ad7a01bca781aaf752ee0c409835db71_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/2ad7a01bca781aaf752ee0c409835db71.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "백합엄마"
#     },
#     "datePublished": "2019-07-18T12:04:50+09:00",
#     "description": "초보주부도 쉽고 간단하게 만들수있는 맛있는 쪽파김치 따뜻한 밥 위에 파김치 하나 올린후 밥 한공기 또는 라면을 아주 맛있게 먹을수 있죠 ㅎㅎ 특히 라면먹을때~^^ 상상 해 보세요 ㅎㅎ"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "2"
#     }
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "6 servings"
#         ,"recipeIngredient": ["쪽파 1단","고추가루 1.5컵","까나리액젓 1컵","찹쌀가루 1/3컵","새우젓 1/3컵","다진마늘 1/2컵","설탕 1/3컵","통깨 약간"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"쪽파는 깨끗이 다듬어서 흐르는물에 흙없이 깨끗하게 씻은후 채에 받쳐 물기를 빼 줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/54cf78bf651acb92ffc1585ac35c55121.jpg"},{"@type":"HowToStep","text":"까나리액젓으로 쪽파흰부분만  절여 줍니다 쪽파는 소금으로 절이면 질겨질수 있기 때문에 액젓으로만 절이는 것이 좋습니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/ab6aca2a652032997d32cd7769ff3c5e1.jpg"},{"@type":"HowToStep","text":"10분정도 후에 쪽파를 뒤집어 줍니다. 골고루 절여 지도록~ 이때 쪽파 절인 까나리젓국물은 버리지 마시고 양념장 만들때 넣어 줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/e3d94b35a7af3b53ea742ea031ed2fb51.jpg"},{"@type":"HowToStep","text":"끓는물에 찹쌀가루넣고 찹쌀풀을 만들어 줍니다 *밀가루풀 또는 찬밥을 믹서기에 갈아서 해도 됩니다 *찹쌀풀 기준; 물1컵, 찹쌀가루 2T","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/18/74124ca9146ff9d49c8e7b01b090a33e1.jpg"},{"@type":"HowToStep","text":"찹쌀풀을 식혀서 고추가루,새우젓 설탕,마늘과 쪽파절인 까나리젓을 넣고 골고루 섞어주면 쪽파김치양념 이 됩니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/7d741a46b2220655695fada73822621d1.jpg"},{"@type":"HowToStep","text":"저는 여기에 통깨도 듬뿍 넣었어요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/c2c2db194b907122fe213916b2fec5b51.jpg"},{"@type":"HowToStep","text":"잘 절여진 쪽파에 양념을 머리흰부분 에 더 많이 발라 주면서 골고루 발라 줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/14daf7ea4e95c435eefba31d81b471851.jpg"},{"@type":"HowToStep","text":"차곡차곡 김치통에 넣어도 되고 먹기좋을 정도로 5~6개씩 돌돌 말아서 켜켜이 담고 살짠 눌러  주세요 상온에서 한나절 두었다가 냉장고에 넣어 드시면 됩니다 쪽파김치 완전 쉽죠^^ 누구나 도전할수있는 맛있는 파김치!!","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/14/f987c4a1fdd1cd579d4738bdf9ebcec81.jpg"}]}
#
# 레시피 ID 6916134에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916191에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916256에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916379에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916430에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916477에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 24 (char 91)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "1+1밑반찬 만들기
# 곤약조림/마늘종돼지안심장조림",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/169325be3d21d0edd95103e8c271c1451_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/169325be3d21d0edd95103e8c271c1451.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "왕눈이2"
#     },
#     "datePublished": "2019-07-26T13:17:24+09:00",
#     "description": "늘상 밑반찬으로 고민중인가요? 곤약조림/마늘종돼지안심조림으로  1+1 밑반찬을 만들어 보세요~"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "3"
#     }
#             ,"totalTime": "PT0H60M"
#             ,"recipeYield": "6 servings"
#         ,"recipeIngredient": ["돼지고기 장조림용 500g","곤약 460g","마늘종 100g","월계수잎 3장","물 600ml","진간장 200ml","설탕 1큰술","올리고당 4큰술","맛술 2큰술","소금 1/2큰술","굴소스 1큰술","후추가루 조금","참기름 1/2큰술","통깨 1큰술"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"돼지고기안심 500g을 찬물에 담구어 핏물을 빼주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/76289837cc782f9669995d4378ea830c1.jpg"},{"@type":"HowToStep","text":"곤약 460g을 준비해주시고  반으로 가르시어 잘라주시고  1센티 두께로 자르신후 가운데 2~3cm의 길이로 칼집을 내신후 끝의 한쪽을 칼집낸곳으로 밀어넣어주세요 꼬임의 모양을 낼수가 있어요 *모양없이 그냥하셔도 상관없어요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/fb1c38ec87508fc398c9faae9f1c138b1.jpg"},{"@type":"HowToStep","text":"끓는물에 식초를 조금만 뿌려서 넣고 곤약을 2분간 데쳐내시고 찬물에 씻어주세요 마늘종도 살짝만 데쳐내셔서  찬물에 씻어주세요 *저는 곤약의 꼬임을 데쳐낸후 씻어서 만들어 주었어요 참고들하세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/807ed22ff7e3eb86a37fd15604f93aca1.jpg"},{"@type":"HowToStep","text":"물 600ml에 간장 200ml와 굴소스 1큰술을 넣고 올리고당 4큰술과 설탕 1큰술을 넣어주신후 잘 섞어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/6a67cb90ccbdd359c423d67f33702d2f1.jpg"},{"@type":"HowToStep","text":"마지막 양념으로 생강술(맛술,미림)2큰술을 넣어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/26/171674c797d31e25b69f3f0f214f63991.jpg"},{"@type":"HowToStep","text":"핏물을 제거한 돼지고기안심에 간장양념물을 부어주시고 월계수잎 3개를 넣어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/5cb1063f253dffad056306ecf8c7a0ad1.jpg"},{"@type":"HowToStep","text":"6번 펄펄 끓여 주시고 돼지고기가 절반정도로 크기가 줄었으면 곤약을 넣어주세요 후추가루 조금만 넣어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/a29e427aece444b5b14af1451c3e4a601.jpg"},{"@type":"HowToStep","text":"곤약도 간장색으로 진하게 물들어 조려지고 간장양념물이 절반아래로 조려지면 데쳐놓은 마늘종을 넣어주세요 여기서 간을 보시고 싱거우시면 소금을 추가하세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/367aecd69ad1432f76f73172c2b4f0831.jpg"},{"@type":"HowToStep","text":"다조려진 조림에 돼지고기안심만 따로 빼내어 잘게 찢어주시고 월계수잎을 건져내시고 남은 곤약과 마늘종/간장양념을 부어주세요 참기름 1/2큰술과 통깨를 뿌려주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/7f91df9b633a59b009c9e0693aa9de461.jpg"},{"@type":"HowToStep","text":"간장양념물이 고루 베이게 잘 섞어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/d229787a82e0c4c5bc037df6a29ecdc51.jpg"},{"@type":"HowToStep","text":"마늘종돼지고기안심조림과 곤약조림이 두가지 밑반찬이  한번에 만들어졌네요 따로 담아서 냉장보관후 드시면 되세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/25/f30e8d172114b2ad05f1c5928858e1d51.jpg"}]}
#
# 레시피 ID 6916531에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6916538에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "삼겹살 필수~!
# 파절이와 고추장 양념 만들기",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/628611f04b560d34ef696f4715316df71_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/628611f04b560d34ef696f4715316df71.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "맛미2"
#     },
#     "datePublished": "2019-07-29T01:28:37+09:00",
#     "description": "삼겹살 먹을때 꼭 필요한 파절이와 고추장 양념장을 만들어 보았습니다  언제 먹어도 맛있는 삼겹살의 맛을 더 업 시켜 주죠~♡"
#             ,"totalTime": "PT15M"
#             ,"recipeYield": "3 servings"
#         ,"recipeIngredient": ["대파","고추가루","식초","설탕","깨","간장","매실청","고추장","올리고당","참기름"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"파절이용으로 자른 대파(대파 2.5개 정도 사용)는 찬물에 5분~10분 정도 담궈 매운 맛을 빼주고 싱싱함을 업시켜주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/8b6358f8b635c8f1caa805fc54e9aac61.jpg"},{"@type":"HowToStep","text":"고추가루4 스푼, 식초3스푼,  양조간장 3스푼, 설탕 3스푼, 참깨 3스푼, 매실청 2스푼을 넣어 잘 버무려 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/d16718ce63d1d442cb62ed79c1b12e741.jpg"},{"@type":"HowToStep","text":"완성입니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/6151d460e3fb9c7dbb34f65f2076912e1.jpg"},{"@type":"HowToStep","text":"삼겹살 먹을때 같이 곁들이면 좋은 고추장 양념장 입니다  고추장 2스푼, 올리고당 1.5스푼, 참기름 1스푼, 통깨 1스푼 넣어 섞으면 맛있는 양념장이 됩니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/7df7cc06dd89627b59fad76820604b0e1.jpg"},{"@type":"HowToStep","text":"완성입니다☆","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/29/7e6c07479beea6388235581fe3d611d01.jpg"}]}
#
# 레시피 ID 6916591에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 31 (char 98)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "비름나물무침~아삭하니 맛있어요.
# 여름밥반찬~",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/22/20146a0b764296b6c4627b8cae0bf4ba1_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/07/22/20146a0b764296b6c4627b8cae0bf4ba1.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "캔캔맘"
#     },
#     "datePublished": "2019-07-30T07:15:18+09:00",
#     "description": "친정어머니가 주신 비름나물로 비름나물 좋아하는 딸래미위해 빨갛게 만들어 봤어요. 아삭하니 씹는 맛이 일품이에요~^^"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "9"
#     }
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "4 servings"
#         ,"recipeIngredient": ["비름나물 400g","다진마늘 2T","고춧가루 2T","고추장 3T","식초 1T","설탕 1T","물엿 2T","들기름 1T","통깨 1t"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"비름나물을 준비 합니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/8fb2193e8ae89019c572aaaa72db14e81.jpg"},{"@type":"HowToStep","text":"비름나물 줄기 굵은 부분은 잘라내 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/59ab95e32fa695385a606244338ef1b51.jpg"},{"@type":"HowToStep","text":"깨끗한 물에 3번정도 씻어 줍니다. 식초 2~3방울 넣고 5분정도 담갔다가 휑궈 주세요.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/1d92a914c193e3b0f8f82cc225a1eae71.jpg"},{"@type":"HowToStep","text":"물 400ml정도 넣고 끓여 줍니다.이때 소금 한수저 넣고 저어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/f3025702b9f8a829a1e0fc3bffbd87271.jpg"},{"@type":"HowToStep","text":"물이 끓으면 살짝 데쳐 줍니다. 비름나물을 집기로 잡고 돌려가며 데쳐 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/cc4060fd939d7e3d1a0ec1c3e5926f431.jpg"},{"@type":"HowToStep","text":"찬물에 휑궈 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/7b85a47304967913eb78499ad72760751.jpg"},{"@type":"HowToStep","text":"채반에 담아 물기를 빼 줍니다. 그리고 손으로 물기를 최대한 꼭 쫘 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/47c302e30ece59a5c50c13fdaa1d62861.jpg"},{"@type":"HowToStep","text":"다진마늘을 넣어 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/d2ff534f0a448e431f54793b841eb9221.jpg"},{"@type":"HowToStep","text":"준비된 양념을 넣고 조물조물 무쳐 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/052772536652ba83cbcb2c8619fcb2551.jpg"},{"@type":"HowToStep","text":"마지막으로 참기름을 넣고 무쳐 줍니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/9b732358db58c8299bfc58cf950ab4b61.jpg"},{"@type":"HowToStep","text":"접시에 담고 통깨를 손으로 으깨 뿌려 줍니다. 비름나물무침 완성입니다.","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/07/21/7a9d8dd80c0f2cac9791e060d1579ad51.jpg"}]}
#
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]
# 오징어 가지볶음~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/01/350abfdce14ac44b2a9985bafe09ce1f1_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/01/350abfdce14ac44b2a9985bafe09ce1f1.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-01T14:14:58+09:00",
#     "description": "완전 쉬운 밑반찬"
#             ,"totalTime": "PT15M"
#             ,"recipeYield": "2 servings"
#         ,"recipeIngredient": ["가지 1개","솔방울오징어 100g","굴소스 조금","카놀라유"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"오징어,가지 듬성 듬성 먹기좋게 썰어 준다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/01/dfeb1a8ae66931f4ff3921a290652f551.jpg"},{"@type":"HowToStep","text":"굴소스 조금 넣고 슥슥  볶아준다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/01/324db5e20cd4aa3ff6304a9df5a32eb61.jpg"},{"@type":"HowToStep","text":"대파 송송 썰어 넣고 휘리릭~ 볶아 접시에 담으면 끝","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/01/4bff16350888bf40c6490fca85aa25721.jpg"}]}
#
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]
# 간편 채소 찹쌀죽~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/c7be0a904390da14a8b6ae16bc9465b31_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/c7be0a904390da14a8b6ae16bc9465b31.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-03T17:46:51+09:00",
#     "description": "감자가 들어가 맛있당 냉장고속 사정에 따라 채소 넣으심 되겠쥬~"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "3"
#     }
#             ,"totalTime": "PT0H60M"
#             ,"recipeYield": "1 servings"
#         ,"recipeIngredient": ["찹쌀 1","감자 1","대파 적당량","당근 적당량","육수 400ml (다시마 멸치)","국간장 1티스푼","참기름 2큰술"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"찹쌀 2시간정도 불려 주었어요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/1faf9fe367e47bde9964da8991e894cb1.jpg"},{"@type":"HowToStep","text":"채소 다져 준비합니다 (채소냉장고속사정에따라)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/bf8b9b8b46a855d3e1cda92da46071a81.jpg"},{"@type":"HowToStep","text":"불린 찹쌀 헹궈준 후 냄비에 담고 준비한 채소도 넣어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/46f5c64ef1b856f93e2dd5135798d1821.jpg"},{"@type":"HowToStep","text":"참기름2큰술 국간장 티스푼1 넣고 슥~ 볶아준 다음","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/560aa02ee0d45adcfd9e4924ce9a4f8d1.jpg"},{"@type":"HowToStep","text":"다시육수를 붓고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/e1a644e79975a4c2c5f18bb5ba4165d11.jpg"},{"@type":"HowToStep","text":"센불에서 보글 보글 끓이다가 약불로 낮춘 후 잘 저어 가면서 끓여준다 걸쭉하게 끓여지면 대파 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/63e4c96ac171aa52657a69d062515be91.jpg"},{"@type":"HowToStep","text":"한소끔 끓여주면 완성","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/03/c5648118f8deb1f80dd8b5a68ab598111.jpg"}]}
#
# 레시피 ID 6916959에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6917030에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6917131에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "초간단 어묵무침
# ",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/771159bc81cca36c0b2d158cdc527fc21_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/771159bc81cca36c0b2d158cdc527fc21.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "깻잎언니"
#     },
#     "datePublished": "2019-08-12T07:15:37+09:00",
#     "description": "어묵은 항상 기름에 볶아서 먹었는데 기름에 볶지않은 요리"
#             ,"totalTime": "PT10M"
#             ,"recipeYield": "3 servings"
#         ,"recipeIngredient": ["사각어묵 3장","작은양파 1/2개","외 간장 1큰술","고추가루 1큰술","참기름 1큰술","통깨 조금"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"어묵을 반자르고  채 썰어요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/80370c3248709b57cc043a023c1cab931.jpg"},{"@type":"HowToStep","text":"달군팬에 기름없이 볶아요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/2acf6640791df8c314209d9afdaa91e81.jpg"},{"@type":"HowToStep","text":"양파 반개 채썰구요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/dd0f290993c81e931c0d30fe1a4968931.jpg"},{"@type":"HowToStep","text":"무칠 그릇에 양념을 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/5ae8de87905ee88c2d41f4dabfa508da1.jpg"},{"@type":"HowToStep","text":"섞어두어요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/749d1e93504b428dd874fdd19963da6e1.jpg"},{"@type":"HowToStep","text":"어묵이 다 볶아지면","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/85d363db0e558b6d9ab4ced6781fb7711.jpg"},{"@type":"HowToStep","text":"양념그릇에 볶은 어묵을 넣고 무쳐요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/12/2313a062583fac8a83912ad6720eb1961.jpg"}]}
#
# 레시피 ID 6917435에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6917489에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6917491에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]
# 초간단 김장무 들기름 볶음밥~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/15/f0fc9319716f3c520ef7401f566f3b421_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/15/f0fc9319716f3c520ef7401f566f3b421.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-15T13:54:58+09:00",
#     "description": "김장무 들기름 볶음밥 들기름 향이 솔솔~ 고소미 새콤한 김장무 씹힘이 어우러져 맛나다 "
#             ,"totalTime": "PT10M"
#             ,"recipeYield": "1 servings"
#         ,"recipeIngredient": ["김장무 적당량","들기름1큰술","밥 1인분 ","굴소스 조금"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"김장무 고춧가루 없이  씻은 후 잘게 썰어준다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/15/7069e583852f7a29b4a82bf6394200681.jpg"},{"@type":"HowToStep","text":"달궈진 팬에 무를 넣고  들기름을 두른 후 약한 불에서 슥슥~ 볶아준다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/15/fd48775e3f9425131596784c7f0ed52c1.jpg"},{"@type":"HowToStep","text":"밥,대파 썰어 넣어준다 굴소스 취향껏 가감하고 슥슥~ 볶아","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/15/08dde7d2df10189b31d4c6277b757e851.jpg"},{"@type":"HowToStep","text":"그릇에 담아 내면 초간단 김장무 볶음밥 만들기 끝","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/15/e7c2481586c88b36a1b42ad963869b7a1.jpg"}]}
#
# 레시피 ID 6917568에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6917645에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 27 (char 94)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]☆저염식☆
# 토마토 묵은지 삼치&두부 전~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/17/3ca13d7f64c65768cf992fec81a0ba791_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/17/3ca13d7f64c65768cf992fec81a0ba791.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-17T16:55:40+09:00",
#     "description": "두부&삼치 토마토 묵은지 전! 영양 듬뿍 든든한 한끼식사로   [콩~두부] 콩에 많이 들어있는 식이섬유가 대장 점막이 발암물질에 노출되는 것을 막아준다고 한다 콩에 들어있는 '이소플라본'이라는 성분은 유사 여성 호르몬의 역할을 하기 때문에 여성에서 대장암 예방에 효과가 있는 것으로 알려졌다고 한다  [등푸른생선삼치] 삼치에 함유된 DHA는 태아의 두뇌발달을 돕고 머리를 좋게 하며 노인들의 치매 예방, 기억력 증진, 암예방에 효과적인 것으로 알려져 있다  [건강식품토마토] 토마토가 건강식품으로 주목받는 가장 큰 이유는 '라이코펜' 때문이다 토마토의 붉은색을 만드는 라이코펜은 노화의 원인이 되는 활성산소를 배출시켜 세포의 젊음을 유지시킨다 또한 라이코펜은 남성의 전립선암, 여성의 유방암, 소화기계통의 암을 예방하는 데 효과가 있다   토마토의 라이코펜과 지용성 비타민은 기름에 익힐 때 흡수가 잘 된다고 합니당  [유산균묵은지] 묵은지는 일반적인 김치와 달리 발효과정에서 젖산균이 생기는데 이는 해로운 세균을 막아주어 병원균으로부터 몸을 보호해준다 묵은지는 혈압을 낮추어주고 암을 예방하는 효능도 있는 것으로 알려졌다  [항암작용들기름] 들기름에는 리놀렌산,로즈마린산 성분이 풍부하게 함유되어 있어 체내 유해한 활성산소를 제거하고 세포손상을 막아주며 세포변이를 억제시켜 암세포의 발생이나 성장 전이 등을 억제시켜 암예방에 효과적이다 "
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "1 servings"
#         ,"recipeIngredient": ["두부 1/2모","삼치 1토막","토마토 1/2개","묵은지2잎","들기름2큰술","맛술1스푼","전분1스푼","올리브유"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"묵은지 고춧가루 없이 헹궈 잘게 송송~ 썰어주세요 토마토 썰어 듬성 듬성 다져주고 토마토에 국물기를 제거하고 준비합니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/b8eba2319555359dcc44c5cd5d2386ba1.jpg"},{"@type":"HowToStep","text":"삼치는 가시와 껍질을  발라 내고 다져 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/26dff76a8050fcae4de7ad56d21a9ec01.jpg"},{"@type":"HowToStep","text":"다진 삼치 볼에 담고  맛술1스푼 넣은 뒤  버무려 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/92db8bac80dea40d4d38b51f62d84c7e1.jpg"},{"@type":"HowToStep","text":"두부 도톰하게 썰어 주시고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/3c4e293f1c0ddfb33f3fa9f0b0c0c1a31.jpg"},{"@type":"HowToStep","text":"둥근 틀을 이용해서  모양을 찍어냅니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/0210cbe12698497cdb101d695f331c321.jpg"},{"@type":"HowToStep","text":"찍어낸 곳에 삼치살을 채워준 후","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/8757cdfe683acb9ae60ccaa0696ec4881.jpg"},{"@type":"HowToStep","text":"전분 옷을 입혀줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/2417697bb78d0ed1f3e0aa01ca79e4311.jpg"},{"@type":"HowToStep","text":"달궈진 팬에 들기름을 두르고 하나식 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/0798a3338b33772282427dd1575e7ee91.jpg"},{"@type":"HowToStep","text":"앞,뒤 노릇하게 구워 (약불로 구워요)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/4ecaa4bc003ce07816331e5c1078e8bf1.jpg"},{"@type":"HowToStep","text":"접시에 담아 냅니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/64110bdda93a23a60b9deadbed1395651.jpg"},{"@type":"HowToStep","text":"준비한 토마토,묵은지 팬에 담고 올리브유를 두른 뒤 슥슥~ 볶아주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/1da131220daeef02f349b384dca06c011.jpg"},{"@type":"HowToStep","text":"볶은 토마토와 묵은지 두부 삼치위 올려주면 완성입니당^^","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/16/6ef707fca1b0db4042adbbf79ccfdf021.jpg"}]}
#
# 레시피 ID 6917728에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]
# 건강 토마토 쥬스~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/979a381c7dc64a2bc59b2e93219facce1_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/979a381c7dc64a2bc59b2e93219facce1.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-19T13:21:15+09:00",
#     "description": "물 전혀 들어가지 않는 건강 토마토쥬스 시원하게 한잔 마시니 건강해 지는 기분  좋슴댜~^^  "
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "3 servings"
#         ,"recipeIngredient": ["토마토 8개","소금1꼬집"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"토마토 식초 물에 깨끗히 씻어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/f40519d74860c9c13445a635c53d7e1c1.jpg"},{"@type":"HowToStep","text":"밑둥을 잘래내고 듬성 듬성 썰어","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/161dd29094dd40e8f6d483168812819d1.jpg"},{"@type":"HowToStep","text":"믹서기에 윙~ 갈아 냄비에 부어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/26b4cf0b17f41b1e1df3c89a680175521.jpg"},{"@type":"HowToStep","text":"바글 바글 끓여","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/06f155bf6766c2eb556a492da13106eb1.jpg"},{"@type":"HowToStep","text":"채에 받쳐 토마토 물만  걸러내면 와성","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/a9e05b4fa5fb4520cd87e2771b82423a1.jpg"},{"@type":"HowToStep","text":"병에 담고 냉장고에 넣은 후 시원하게 드심됩니다요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/19/336aa61ec5a198749002edcc626c3cf61.jpg"}]}
#
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 22 (char 89)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]
# 들깨 샐러드 사과 카나페~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/844ca7f6678570e802fdc466f67e9a961_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/844ca7f6678570e802fdc466f67e9a961.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-20T19:58:21+09:00",
#     "description": "계란 감자 샐러드 건강에 좋은 들깨가루를 넣고 버무려 보았어요 사과에 올려 먹으니 사과에 달콤함이 쏴~ 감싸져 맛을 더 업 시켜주네요 엄지척! 들깨는 고소한 맛이 일품일 뿐만 아니라 우리 인체에 유익한 성분이 풍부하게 함유되어 있어 건강에도 좋다고 하죠 사과는 사과에 들어 있는 펙틴이 식이섬유의  한 종류로 대장에서 독소를 제거하고 장의  연동운동을 촉지시켜 변비와 설사에 효과적 이라고 합니다 그리고 지방산을 증가시켜 대장암 예방에도 도움을 준다합니다 "
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "3 servings"
#         ,"recipeIngredient": ["달걀 3개","감자 3개","취청오이 1/2개","당근","홍파프리카","마요네즈 2큰술","원당 1/2스푼","들깨가루 2큰술"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"감자는 필러로 껍질을 벗기고 반을 자른 후 익을때 까지 삶아주고 계란은 소금 티스푼1넣고 10분정도 삶아 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/4fbf5a397f093cfc5bbfef506b7fa6331.jpg"},{"@type":"HowToStep","text":"감자와 계란을 삶는 동안 채소 다져 준비합니다 (오이는 중간 씨부분을 빼고 다져 주세요)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/e0870f048d2e76b069d154c38bbccd7e1.jpg"},{"@type":"HowToStep","text":"계란은 껍질을 벗겨준 다음 감자 계란 볼에 담고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/086f46b6778c90358bdb31127c7552ea1.jpg"},{"@type":"HowToStep","text":"포크나 도구를 이용해서 으깨어 줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/9cb650992ef324e954e21cba7fea5d561.jpg"},{"@type":"HowToStep","text":"준비한 채소 담고 원당 반큰술 마요네즈 2큰술 들깨가루 2큰술 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/c85b13f567c220669405a1b8f175395f1.jpg"},{"@type":"HowToStep","text":"고루 섞어 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/d621a1da837dd723bb194511491bcfc11.jpg"},{"@type":"HowToStep","text":"사과를 깨끗히 씻은 후 위 밑둥을 잘라내고 도톰하게 썰어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/2776c2f114f643894a6d5f25779cd9be1.jpg"},{"@type":"HowToStep","text":"모형틀을 이용해서 사과 씨 부분을 찍어 냅니다 (씨부분만 칼로 잘라 내셔도ok)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/826d57f1511d68d58676125941fe158e1.jpg"},{"@type":"HowToStep","text":"만들어 놓은 샐러드를 올려","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/fa4e1ee1a2e488c0119dc09556b2df951.jpg"},{"@type":"HowToStep","text":"접시에 담아 내면 완성입니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/17328abab095048819e80764ac2b0c391.jpg"},{"@type":"HowToStep","text":"사과를 깍아 발라 먹어도 좋아요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/20/a4807364740ba13e558136e9124ec8211.jpg"}]}
#
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 34 (char 101)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피] 귀리버섯패티를 이용한
# 채식 샌드위치 ",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/01eb8f7aa5ddfbd1fd57110734e51bb51_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/01eb8f7aa5ddfbd1fd57110734e51bb51.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "깻잎언니"
#     },
#     "datePublished": "2019-08-21T10:30:47+09:00",
#     "description": "귀리가루위 갈은 버섯을 넣어 반죽해서 패티를 만들었는데 엄청 맛있는 채식 샌드위치가 되었어요 고기없이 고기맛과 식감이나는 패티 야채는 냉장고에 있는 재료로했어요 상추가 없어서 단배추잎으로 했는데 하나도 거슬리는것 없었어요"
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "2 servings"
#         ,"recipeIngredient": ["귀리가루 80g","표고버섯 작은것 7개 (불린것)","새송이 큰것2개","위에 두가지 버섯 다진것 중에 120g","곡물식빵 4장","양배추 조금","적양파 조금","파프리카 조금","단배추잎 조금","오이 조금","마늘소스 6큰술","진간장 1큰술","물 2큰술","올리고당 2큰술","후추 조금","다진마늘 조금","참기름 1큰술"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"불린표고는 물을 짜지 않았어요 반죽할때 물이필요하니까요 버섯들을 작게 잘라요 잘 갈아지라고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/5f6272243ced74fd3f3d5f5ba470dca71.jpg"},{"@type":"HowToStep","text":"분솨기에 갈아요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/4891feb5d2fda881f545752699babdc61.jpg"},{"@type":"HowToStep","text":"귀리가루에","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/01f825ce36d5c8930546651c46c20b671.jpg"},{"@type":"HowToStep","text":"버섯다진걸 넣고 반죽해요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/a526e7061a92dc980de3c1c01db8a5881.jpg"},{"@type":"HowToStep","text":"식빵크기로 반죽 모양을 잡아서 끓는 물에 2분에서3분 정도 끓여요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/c3a17cf75d7f129d54f356a975ca2f511.jpg"},{"@type":"HowToStep","text":"팬에 양념장을 넣고 끓여요 끓으면 귀리버섯패티를 건져서 졸여요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/2ff562c9d18f1e89719c868a8c2698e91.jpg"},{"@type":"HowToStep","text":"간이베이게 쫄깃하고 불고기 양념맛 나는게 고기 같아요ㅎ","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/ed9a21ddb4e7ee2b63641f7db0b474eb1.jpg"},{"@type":"HowToStep","text":"야채에 마늘 소스로 버무려요 @6917891","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/e69ec8a7b07f1ddd16c3e180d23ff98c1.jpg"},{"@type":"HowToStep","text":"빵에도 마늘소스 발라요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/42950008480d8d51c1febb2c627f4fa71.jpg"},{"@type":"HowToStep","text":"두쪽다 발라요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/52dd226ec886c6303ff81f502488de2d1.jpg"},{"@type":"HowToStep","text":"빰에 야채올리고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/96ccaebe88e71c06334d40b63f8f27a71.jpg"},{"@type":"HowToStep","text":"양파도올리고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/f2acf8bf1cd18f5c36dc01c85ea1f7411.jpg"},{"@type":"HowToStep","text":"간장양념에 졸인 패티도올리고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/7b65401974d2544f7ca822b1fabec0201.jpg"},{"@type":"HowToStep","text":"오이 올려서","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/d8c0e954d6ac57ff6e9ee631f06912b01.jpg"},{"@type":"HowToStep","text":"나머지 빵으로 덮어서 완성 이에요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/21/ab7eebf80befd6f18cf624955638bc0a1.jpg"}]}
#
# 레시피 ID 6917942에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6917981에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 32 (char 99)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피] ☆저염식 밑반찬☆
# 양배추 닭가슴살 무침~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/5210526e2c56f463193089d97685a5b11_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/5210526e2c56f463193089d97685a5b11.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-22T21:51:07+09:00",
#     "description": "저염식으로 만든 건강 밑반찬 양배추 닭가슴살 무침"
#         ,"aggregateRating": {
#         "@type": "AggregateRating",
#         "ratingValue": "5",
#         "reviewCount": "1"
#     }
#             ,"totalTime": "PT15M"
#             ,"recipeYield": "6 servings"
#         ,"recipeIngredient": ["양배추 210g","당근 적당량","닭가슴살100g","히말라야핑크 소금 2꼬집","다진마늘 1스푼","들기름 2큰술"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"양배추 흐르는 물에 헹군 후 비닐팩에 넣고 묵지않고 전자렌지에 야채데치기 기능으로 4분정도 데쳐주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/e66b3dced794a2a6f1208336c1ed5e561.jpg"},{"@type":"HowToStep","text":"그사이 당근 잘게 채썰어 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/98b0b5073154e24f7289420a7c0dfb461.jpg"},{"@type":"HowToStep","text":"양배추,당근 볼에 담고 삶은 닭가슴살 찢어 넣는다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/ef2b742cbac232c5746e5e114fb4c8b21.jpg"},{"@type":"HowToStep","text":"다진마늘 1스푼 희말라야핑크소금 2꼬집 들기름2큰술 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/c5a95583354407a26549c2085608f7d91.jpg"},{"@type":"HowToStep","text":"슥슥~ 무쳐 그릇에  담아내면 간단 밑반찬 만들기 완성~","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/2bfab2bfed0bdd9e78d6cd8b3a757d471.jpg"}]}
#
# 레시피 ID 6918034에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6918066에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 6918067에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 31 (char 98)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피] ☆저염☆도시락☆
# 묵은지 품은 통오이 김밥 ~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/d846067f4cf5941deca469d4b3176bc71_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/d846067f4cf5941deca469d4b3176bc71.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-23T16:19:18+09:00",
#     "description": "묵은지 품은 통오이 김밥 묵은지가 간을 잡아주니 저염식으로 드실수 있겠죵 든든 한끼 식사로 딱~ "
#             ,"totalTime": "PT15M"
#             ,"recipeYield": "1 servings"
#         ,"recipeIngredient": ["취청오이 1개","묵은지 3잎","밥","들기름1큰술","소금1꼬집"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"오이 깨끗히 씻은 후 플라스틱 굵은 빨대로 속을 파 주었어요 (적당한 도구 이용하심 됩니다)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/aa11c32dfb6450e85bc0b71284b608391.jpg"},{"@type":"HowToStep","text":"필러로 껍질을 벗겨냅니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/1820d19f6e40fdaa779871e570b0b7fc1.jpg"},{"@type":"HowToStep","text":"묵은지 씻어 잘게 송송 썰어주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/d12fcc9fb40ed3c7e82ac7a98c5240961.jpg"},{"@type":"HowToStep","text":"속을 파낸 오이에 묵은지 꽉 꽉 채워주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/b44970b4dc4e419ff300572b1a18a4871.jpg"},{"@type":"HowToStep","text":"볼에 밥 1인분량 담고 들기름1스푼 소금1꼬집 넣고 비벼주세요 (소금 패슈 하셔도 됩니당)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/9807a6b7e0b336f16fd91870f76098b91.jpg"},{"@type":"HowToStep","text":"김 위에 밥 깔아주고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/3a71ecbf0db0114dc4171f188f6131a51.jpg"},{"@type":"HowToStep","text":"준비한 오이 올리고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/db7184712ace6e1d1bf46174ffcd12301.jpg"},{"@type":"HowToStep","text":"도르르 말아","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/41834ff519c3ba734ea10b0321e990c31.jpg"},{"@type":"HowToStep","text":"먹기 좋은 크기로 썰어 도시락에 담으면 묵은지 품은 통오이 김밥 만들기 끝","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/23/bc32387dd8f7aff248354f15244fa6091.jpg"}]}
#
# 레시피 ID 6918097에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 31 (char 98)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피]☆저염식☆도시락☆
# 황태가루 김장무 들기름 볶음밥&애호박 달걀 플라워~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/42d99151efa4fbc72cf7e482b8e726541_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/42d99151efa4fbc72cf7e482b8e726541.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-25T18:24:32+09:00",
#     "description": "눈도 입도 즐거운 나만의 암예방 건강 도시락~* 도시락 뚜껑을 여는 순간 눈이 즐거워 지겠죵 소금간은 따로 하지 않아도 김장무와 황태가루가 간을 잡아 주네요 들기름에 볶아 고소합니다 저염식 든든 한끼 식사로 딱이겠쥬~ "
#             ,"totalTime": "PT30M"
#             ,"recipeYield": "1 servings"
#         ,"recipeIngredient": ["황태가루 취향껏","김장무1토막","취청오이1/3개","들기름2큰술","소금 아주조금","달걀1개","애호박4개","카놀라유 조금 "]    ,"recipeInstructions": [{"@type":"HowToStep","text":"황태포 커트기에 넣고 윙~ 윙~ 갈아서 준비합니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/f992fc99689e32cf96855f5706711ebb1.jpg"},{"@type":"HowToStep","text":"김장무,취청오이 1인분량 다져","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/3f2909ae2f0fe2a304cb2f608e4b6f931.jpg"},{"@type":"HowToStep","text":"팬에 담고 들기름2큰술","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/0dc98267de3c48d11bbae9eb7cc6a22a1.jpg"},{"@type":"HowToStep","text":"소금 조금~ 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/b7edccc80c1441d49adc109026cf99c71.jpg"},{"@type":"HowToStep","text":"약불에서 슥슥~ 볶아주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/8ab19d35305801adc9370cbcea6f10dd1.jpg"},{"@type":"HowToStep","text":"1인분량 밥 (귀리,녹미,찹쌀) 투하~ 슥슥 볶아준 다음","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/3b8faaedc3d66040668d446fc26a38941.jpg"},{"@type":"HowToStep","text":"준비한 황태가루 취향껏 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/a4b3c7b1d073e0336c0a09a6787eb2701.jpg"},{"@type":"HowToStep","text":"스윽~ 볶아 주세요 다음은 달걀 플라워  만들러 슈웅~~^^ >>>","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/100aa5129d33227741cf6920ab2fd70e1.jpg"},{"@type":"HowToStep","text":"애호박 동그랗게 조금 도톰히 썰어 반을 자르고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/267c8c9e073b475d95f06ca9adca16311.jpg"},{"@type":"HowToStep","text":"동그란 모양 틀로 사진처럼 찍어 냅니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/a695080928e8ed122a1b8cb44e2ef7821.jpg"},{"@type":"HowToStep","text":"팬을 불에 올리기전  호박으로 꽃모양을 만든 후 기름을 조금 두르고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/0b42de4b4ccc30522c5e4e0adecf20a71.jpg"},{"@type":"HowToStep","text":"약불에서 조심히 계란1 탁~ 깨넣고 구워줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/1dc8bcd47eeba2deed39be99eaaba21a1.jpg"},{"@type":"HowToStep","text":"도시락에 준비한 밥을 담고 취향에 따라 황태가루 뿌련준 후","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/564b6a0f2ba1e86adaf557fae8ef273b1.jpg"},{"@type":"HowToStep","text":"애호박 달걀 플라워를 밥 위 올려 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/dfab634dcfa5bc4f71e509dab472983b1.jpg"},{"@type":"HowToStep","text":"김으로 눈과 입을 만들어 붙히고 사이드로 방울토마토 쏘~ 옥~~ 넣어주심 나만에 암예방 건강 도시락 만들기 완성 입니다^^","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/22/9a471b369ca874842a96f47afd12a4001.jpg"}]}
#
# 레시피 ID 6918197에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 30 (char 97)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[암예방레시피] ☆저염☆보양☆
# 두부 채소 한우 스지탕~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/8824a40bdff8bd6c93a4986f6516c4031_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/8824a40bdff8bd6c93a4986f6516c4031.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-26T21:03:47+09:00",
#     "description": "맛 영양 가격 셋다 잡아버린 스지~ 스지는 소 힘줄을 말합니다 스지의 풍미와 쫄깃한 식감 맛이 좋슴댜"
#             ,"totalTime": "PT0H60M"
#             ,"recipeYield": "2 servings"
#         ,"recipeIngredient": ["한우200g","두부100g","애호박50g","당근50g","감자1개","통마늘5개","월계수잎3잎","생강1개","맛술3큰술","새우젓국물1스푼","후추 톡"]    ,"recipeInstructions": [{"@type":"HowToStep","text":"30분 정도 핏물을 갈아 가면서 핏물을 빼줍니다 (작은 양이라 30분만 뺐어요)","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/b54b3fd66d1843a02e9f4ddee28332ed1.jpg"},{"@type":"HowToStep","text":"소주(소주잔)1컵 붓고 스지가 잠길 정도 물을  부어준 뒤 10분정도 끓여 물은 버리고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/9abd443faa668d75370e3185d5ce65ef1.jpg"},{"@type":"HowToStep","text":"스지는 찬물에 헹궈  먹기 좋게 썰어","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/db132fd5817e335f147f4d7b8242d6e61.jpg"},{"@type":"HowToStep","text":"냄비에 담고 월계수잎,통마늘,생강  맛술 넣어 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/0189d6afe7ce57b57ab43bb9dbf7d4031.jpg"},{"@type":"HowToStep","text":"물 1200ml 붓고 센불에서 끓어 오르면 중불 약불로 낮추어 끓여 줍니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/27aab188305a55ca2e2d1fe2eb25839f1.jpg"},{"@type":"HowToStep","text":"그사이 채소 두부 썰어 준비합니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/0756f332f8d1a06a2b1d6d288950f84b1.jpg"},{"@type":"HowToStep","text":"푸욱~ 끓으면 통마늘은  빼고 월계수잎 생강은 건져 버립니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/27cb7f3a77e06e0c94c9f098c4d71cc11.jpg"},{"@type":"HowToStep","text":"준비한 감자 당근 넣고 끓여 주다가","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/a850ec70006a636f0a6438718ec0de1a1.jpg"},{"@type":"HowToStep","text":"두부,애호박 넣고 끓여 주세요","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/c48cdd0e2abe71b25a7bca6bdd4e13da1.jpg"},{"@type":"HowToStep","text":"새우젓 국물 1스푼~ 후추 톡~ 넣고","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/0e299dbeb299ddb5041d437028473c451.jpg"},{"@type":"HowToStep","text":"한소끔 끓여 내면 완성 입니다","image":"https://recipe1.ezmember.co.kr/cache/recipe/2019/08/25/4101db409cec7c2c6f2fffb1a5224fc71.jpg"}]}
#
# 레시피 ID 6918333에 본문 데이터가 없어 건너뜁니다.
# JSON 데이터 파싱 실패: Invalid control character at: line 5 column 32 (char 99)
# 수정된 JSON:
#
# {
#     "@context": "http://schema.org/",
#     "@type": "Recipe",
#     "name": "[☆명절,추석☆] 황태가루 들어간
# 담백한 채소 두부전~*",
#     "image": [
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/28/00e0cb3d9cd4bc1aa20b5dc885e5446c1_f.jpg",
#         "https://recipe1.ezmember.co.kr/cache/recipe/2019/08/28/00e0cb3d9cd4bc1aa20b5dc885e5446c1.jpg"
#     ],
#     "author": {
#         "@type": "Person",
#         "name": "밥차리라"
#     },
#     "datePublished": "2019-08-28T11:06:01+09:00",
#     "description": "한입 베어무니 바로 황태 향이 솔~ 나는게 담백 고소 하니 맛나요  "
# ...
# 레시피 ID 7028207에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028272에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028396에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028572에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028584에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028630에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028697에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 702871에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028800에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028888에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7028904에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7029156에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7029313에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7029348에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7029472에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7029688에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7029926에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030043에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030117에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030222에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030578에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030714에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030744에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7030819에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 703105에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031139에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031208에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031223에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031563에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031631에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031716에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 703175에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7031847에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 703187에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032496에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032567에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032594에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032685에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 703274에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032814에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032880에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7032948에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033064에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033261에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033581에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033804에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033817에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033878에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7033946에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7034116에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7034267에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 703427에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7034417에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7034566에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7034728에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7034937에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035048에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035121에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035272에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035341에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035432에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035488에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035761에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7035831에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 703624에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7036299에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7036409에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7036494에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7036627에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7036655에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7036878에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037005에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037074에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037486에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037580에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037902에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037992에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7037999에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038078에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038135에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038192에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038216에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038323에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038375에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038710에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038934에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7038958에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039169에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039170에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039269에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039274에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039365에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039684에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039710에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7039890에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040078에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040117에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040270에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040435에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040581에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040743에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 7040745에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 704352에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 704390에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 705309에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 705508에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 705706에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 705797에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 706230에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 707529에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 708629에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 708861에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 709228에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 709926에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 710025에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 710508에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 710519에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 711081에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 711713에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 711848에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 712197에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 712758에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 713027에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 713227에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 714002에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 714096에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 714295에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 715324에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 715344에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 716139에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 716215에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 716267에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 716642에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 717875에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 717877에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 718054에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 718414에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 718545에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 718549에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 718552에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 719053에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 719453에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 719524에 본문 데이터가 없어 건너뜁니다.
# Error occurred while requesting https://m.10000recipe.com/recipe/721120: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Retrying in 5 minutes... Attempt 1/5
# 레시피 ID 721120에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 721596에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 722485에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 723218에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 723442에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 723814에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 724931에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 725028에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 726027에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 726028에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 726311에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 727032에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 728016에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 728466에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 728983에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 729688에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 730563에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 730686에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 730782에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 731204에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 731216에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 731221에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 731334에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 731572에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 732247에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 732690에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 732975에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 733229에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 733492에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 733629에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 734200에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 734547에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 735254에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 735354에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 735702에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 736239에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 736847에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 736854에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 741566에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 742036에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 743897에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 744097에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 744522에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 744721에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 745017에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 745499에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 745576에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 746039에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 746065에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 746519에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 746828에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 747084에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 747139에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 747733에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 747883에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 748463에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 748466에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 749006에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 750071에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 759497에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 761154에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 761189에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 761272에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 764539에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 764917에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 765051에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 767203에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 767519에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 768201에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 769178에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 769807에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 769862에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 769955에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770198에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770306에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770471에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770976에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770979에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770983에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 770986에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 771221에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 772403에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 773283에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 773432에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 773589에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 775090에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 775729에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 776338에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 776436에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 778156에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 778838에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 779137에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 780498에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 781205에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 782712에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 78288에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 783159에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 783523에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 783613에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 785360에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 785394에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 785428에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 785665에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 787676에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 787967에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 790676에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 790851에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 792087에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 792630에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 807198에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 808208에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 812089에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 813758에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 814883에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 818217에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 818473에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 819747에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 821180에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 822139에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 823463에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 823606에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 824612에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 827080에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 827710에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 828095에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 828156에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 828167에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 828179에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 828441에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 829881에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 830302에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 830356에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 830360에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 832817에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 835226에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 835229에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 835622에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 837250에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 837435에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83756에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83758에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83760에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83761에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83764에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83767에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83768에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 83772에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 838788에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 839775에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 840590에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 840690에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 841164에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 841552에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 841938에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 842361에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 843602에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 843615에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 845351에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 846077에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 846781에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 847370에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 848564에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 849845에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 85001에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 85002에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 850332에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 850924에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 851052에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 851581에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 852714에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 854138에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 854306에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 854796에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 855308에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 856005에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 86508에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 87015에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 87444에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 87735에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 87760에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 88411에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 88577에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 88865에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 88907에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 89258에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 89260에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 89263에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 896605에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 89695에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 89707에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 897366에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 897793에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 899034에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 899164에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 90119에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 90120에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 902904에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 907566에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 907662에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 908293에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 908784에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 908853에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 911244에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 913966에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 91755에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 91952에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 919920에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 920320에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 920706에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 92074에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 92075에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 92184에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 921987에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 922398에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 922553에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 923948에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 924015에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 924697에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 925220에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 92566에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 93044에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 931576에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 934659에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 935223에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 935307에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 93583에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 938504에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 938510에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 938654에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 94234에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 94238에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 944711에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 94573에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 94578에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 94660에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 94669에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 947103에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 948352에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 948887에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 950383에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 950517에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 951714에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 952681에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 95372에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 954032에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 95467에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 956192에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 957766에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 958025에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 958027에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 958043에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 958903에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 961690에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 962988에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 965525에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 965564에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 967562에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 967794에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 968727에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 96923에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 969633에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 96980에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 969801에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 969855에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 96992에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 970360에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 971596에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 972398에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 972411에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 972666에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 972677에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 973381에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 97347에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 973719에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 974300에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 974305에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 974953에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 975639에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 97593에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 976253에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 976509에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 977099에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 977217에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 977504에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 977827에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 978055에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 978449에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 978450에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 980205에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 980209에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 980247에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 980583에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 980734에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 981816에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 983858에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 984200에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 984459에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985205에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985449에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985456에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985548에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985601에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985608에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 985611에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 987120에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 988093에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 988418에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 988420에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 988557에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 989319에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 989958에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 990134에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 990420에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 99045에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 99118에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 991535에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 99175에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 992006에 본문 데이터가 없어 건너뜁니다.
# Error occurred while requesting https://m.10000recipe.com/recipe/993687: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# Retrying in 5 minutes... Attempt 1/5
# 레시피 ID 993687에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 995691에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 996182에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 99622에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 996646에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 99698에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 997209에 본문 데이터가 없어 건너뜁니다.
# 레시피 ID 997291에 본문 데이터가 없어 건너뜁니다.
# recipe_ids.txt 업데이트 완료: 1969개의 ID 남음.
